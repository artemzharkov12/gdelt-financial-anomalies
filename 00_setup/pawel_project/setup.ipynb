# %% [markdown]
# # Setup
# Runs one-time environment setup: restarts Python, loads the config module, then creates the catalog schema and volume if they don't exist.

# %%
# Clear any stale library state before importing
dbutils.library.restartPython()

# %%
# Load shared config — defines catalog/schema/volume names and setup functions
import config

# %%
# Create the music_analytics schema and raw_landing_zone volume if they don't exist
config.setup_schema_and_volume()

# %% [markdown]
# # Setup
# Runs one-time environment setup: restarts Python, loads ``music_pipeline_setup``, then creates the music analytics schema and raw landing volume if they do not exist.

# %%
# Clear any stale library state before importing
dbutils.library.restartPython()

# %%
# Load music_pipeline_setup — defines catalog/schema/volume constants and setup functions
import music_pipeline_setup as config

# %%
# Create the music_analytics schema and raw_landing_zone volume if they don't exist
config.setup_schema_and_volume()
